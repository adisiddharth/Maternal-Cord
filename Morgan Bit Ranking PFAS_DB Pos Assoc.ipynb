# %%
# obtain the Morgan bits that are positively correlated 
# with log CM in the PFAS database

# %%
from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw
from IPython.display import SVG

# %% [markdown]
# # Bit 807

# %%
molecule1 = Chem.MolFromSmiles('OC(=O)C(F)(F)C(F)OC(F)(F)C(F)(F)F') # convert SMILES to mol format and store it
molecule1

# %%
bi1 = {}
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1) # use the mol file to calculate Morgan fingerprint bits
fp_arr1 = np.zeros((1,)) # initialize empty numpy array
DataStructs.ConvertToNumpyArray(fp1, fp_arr1) # add the morgan bits to the empty numpy array
np.nonzero(fp_arr1) # Get the bits present in the molecule
# Out:
# (array([  1,  10,  16,  26,  59, 114, 389, 406, 429, 499, 550, 650, 695,
#         759, 807, 813, 820, 852, 893, 904, 937, 953], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,807,bi1) # Get the structure of the morgan bit
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EFA2C8C8>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('OC(=O)C(F)OC(F)(F)C(F)(F)OC(F)(F)F')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([  1,  26, 114, 221, 253, 278, 385, 389, 403, 406, 429, 435, 508,
#         650, 651, 667, 695, 759, 795, 807, 820, 893, 904], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,807,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EFA158C8>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('OC(=O)C(F)OC(F)(F)C(F)(F)C(F)(F)F')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([  1,  26,  59,  89, 114, 267, 374, 389, 403, 406, 429, 435, 508,
#         650, 651, 695, 759, 807, 820, 886, 893, 904], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,807,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EFA02B08>

# %%
img.save("molecule3.png")

# %% [markdown]
# # Bit 147

# %%
molecule1 = Chem.MolFromSmiles('NC1=C(Br)C=C(OC(F)(F)C(F)C(F)(F)F)C=C1Br')
molecule1

# %%
bi1 = {}
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1)
fp_arr1 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp1, fp_arr1)
np.nonzero(fp_arr1)
# Out:
# (array([  1,  26,  53,  68,  87, 114, 136, 147, 275, 283, 322, 356, 410,
#         429, 433, 512, 518, 527, 533, 548, 561, 607, 695, 728, 833, 849,
#         875, 904], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,147,bi1)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EF9BF0C8>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('NC1=C(Br)N=C(OC(C(F)(F)F)C(F)(F)F)C=C1')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([  1, 114, 136, 147, 250, 324, 329, 347, 356, 378, 402, 429, 433,
#         494, 496, 546, 607, 628, 664, 695, 719, 726, 728, 831, 842, 849,
#         904, 910, 993], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,147,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EFA11908>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('NC1=C(Br)C(SC(F)(F)C(F)(F)C(F)(F)F)=C(Br)C=C1Br')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([ 59, 114, 116, 147, 230, 244, 275, 283, 352, 356, 374, 429, 433,
#         434, 466, 607, 678, 692, 728, 782, 824, 833, 849, 875, 886, 904,
#         937, 949], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,147,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EFA42B48>

# %%
img.save("molecule3.png")

# %% [markdown]
# # Bit 429

# %%
molecule1 = Chem.MolFromSmiles('FC(F)(F)C(=C=C[N+]#N)C(F)(F)F')
molecule1

# %%
bi1 = {}
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1)
fp_arr1 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp1, fp_arr1)
np.nonzero(fp_arr1)
# Out:
# (array([ 51, 114, 132, 200, 254, 360, 429, 487, 490, 505, 596, 674, 694,
#         723, 807, 853, 904, 948, 967], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,429,bi1)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EF916E88>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('OC(=O)C(F)(C(F)C(F)(F)F)C(F)(F)F')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([  1,  26,  47,  50,  59, 114, 136, 187, 306, 389, 410, 429, 561,
#         650, 807, 849, 893, 904, 953], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,429,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EF9F74C8>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('OC(=O)C1(C(F)(F)F)C(F)(F)C1(F)F')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([ 27,  36,  82, 114, 184, 233, 251, 389, 429, 650, 672, 737, 807,
#         849, 893, 902, 904], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,429,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EF921188>

# %%
img.save("molecule3.png")

# %% [markdown]
# # Bit 114

# %%
molecule1 = Chem.MolFromSmiles('OC(=O)C(F)C(F)(C(F)(F)F)C(F)(F)F')
molecule1

# %%
bi1 = {}
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1)
fp_arr1 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp1, fp_arr1)
np.nonzero(fp_arr1)
# Out:
# (array([  1,  26,  59, 114, 216, 224, 389, 429, 479, 650, 771, 807, 820,
#         890, 893, 904, 937], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,114,bi1)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EFA5F408>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('OC(=O)C(F)(C(F)F)C(F)F')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([  1,  26, 114, 371, 389, 399, 429, 623, 650, 807, 893, 904, 909,
#         953], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,114,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EF921E48>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('NC1=C(Br)C=C(OC(F)(F)C(F)C(F)(F)F)C=C1Br')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([  1,  26,  53,  68,  87, 114, 136, 147, 275, 283, 322, 356, 410,
#         429, 433, 512, 518, 527, 533, 548, 561, 607, 695, 728, 833, 849,
#         875, 904], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,114,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EF6EF2C8>

# %%
img.save("molecule3.png")

# %% [markdown]
# # Bit 433

# %%
molecule1 = Chem.MolFromSmiles('NC1=C(Br)C=C(C2=C1C=CC=N2)C(F)(C(F)(F)F)C(F)(F)F')
molecule1

# %%
bi1 = {}
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1)
fp_arr1 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp1, fp_arr1)
np.nonzero(fp_arr1)
# Out:
# (array([ 19,  59,  64, 107, 114, 119, 147, 150, 275, 283, 333, 356, 377,
#         378, 419, 428, 429, 433, 448, 457, 549, 607, 658, 676, 700, 726,
#         728, 833, 842, 849, 875, 904, 915], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,433,bi1)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EFAB8888>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('OC(CC=C)(C(F)(F)F)C(F)(F)C(F)(Cl)C(F)(F)Cl')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([  59,   80,  114,  178,  204,  342,  362,  374,  425,  429,  433,
#          597,  621,  638,  659,  694,  803,  807,  872,  884,  904,  928,
#          940,  989, 1012], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,433,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EFA15AC8>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('CC1=C(C=CC(N)=C1)C(O)(C(F)(F)F)C(F)(F)F')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([  0,  33,  59, 114, 144, 147, 169, 328, 356, 367, 419, 429, 433,
#         623, 647, 698, 726, 807, 845, 849, 875, 884, 885, 888, 891, 904],
#        dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,433,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x231EFA82A48>

# %%
img.save("molecule3.png")
