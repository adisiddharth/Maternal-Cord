# %%
# plot true vs predicted values for the PFAS_DB predictions

# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
# %matplotlib inline
import numpy as np

# %%
# load in RF csv (lipid adjusted)
rf_train_adjust = pd.read_csv('forest_plus_tr_PFAS_adjust.csv')
rf_test_adjust = pd.read_csv('forestplus_ts_PFAS_adjust.csv')

# %%
# load in ANN csv (lipid adjusted)
ann_train_adjust = pd.read_csv('ANN_plus_tr_PFAS_adjust.csv')
ann_test_adjust = pd.read_csv('ANN_plus_ts_PFAS_adjust.csv')

# %%
# load in SVM csv (lipid adjusted)
svm_train_adjust = pd.read_csv('svmdata_tr_PFAS_adjust.csv')
svm_test_adjust = pd.read_csv('svmdata_ts_PFAS_adjust.csv')

# %%
# load in RF csv (lipid non-adjusted)
rf_train_non_adjust = pd.read_csv('forest_plus_tr_PFAS_non_adjust.csv')
rf_test_non_adjust = pd.read_csv('forestplus_ts_PFAS_non_adjust.csv')

# %%
# load in ANN csv (lipid non-adjusted)
ann_train_non_adjust = pd.read_csv('ANN_plus_tr_PFAS_non_adjust.csv')
ann_test_non_adjust = pd.read_csv('ANN_plus_ts_PFAS_non_adjust.csv')

# %%
# load in SVM csv (lipid non-adjusted)
svm_train_non_adjust = pd.read_csv('svmdata_tr_PFAS_non_adjust.csv')
svm_test_non_adjust = pd.read_csv('svmdata_ts_PFAS_non_adjust.csv')

# %%
# separate true and predicted in RF (lipid adjusted)
rf_train_true_adjust = rf_train_adjust['true_values']
rf_train_pred_adjust = rf_train_adjust['predicted_values']
rf_test_true_adjust = rf_test_adjust['true_values']
rf_test_pred_adjust = rf_test_adjust['predicted_values']

# %%
# separate true and predicted in ann (lipid adjusted)
ann_train_true_adjust = ann_train_adjust['true_values']
ann_train_pred_adjust = ann_train_adjust['predicted_values']
ann_test_true_adjust = ann_test_adjust['true_values']
ann_test_pred_adjust = ann_test_adjust['predicted_values']

# %%
# separate true and predicted in svm (lipid adjusted)
svm_train_true_adjust = svm_train_adjust['true_values']
svm_train_pred_adjust = svm_train_adjust['predicted_values']
svm_test_true_adjust = svm_test_adjust['true_values']
svm_test_pred_adjust = svm_test_adjust['predicted_values']

# %%
# separate true and predicted in RF (lipid non-adjusted)
rf_train_true_non_adjust = rf_train_non_adjust['true_values']
rf_train_pred_non_adjust = rf_train_non_adjust['predicted_values']
rf_test_true_non_adjust = rf_test_non_adjust['true_values']
rf_test_pred_non_adjust = rf_test_non_adjust['predicted_values']

# %%
# separate true and predicted in ann (lipid non-adjusted)
ann_train_true_non_adjust = ann_train_non_adjust['true_values']
ann_train_pred_non_adjust = ann_train_non_adjust['predicted_values']
ann_test_true_non_adjust = ann_test_non_adjust['true_values']
ann_test_pred_non_adjust = ann_test_non_adjust['predicted_values']

# %%
# separate true and predicted in svm (lipid non-adjusted)
svm_train_true_non_adjust = svm_train_non_adjust['true_values']
svm_train_pred_non_adjust = svm_train_non_adjust['predicted_values']
svm_test_true_non_adjust = svm_test_non_adjust['true_values']
svm_test_pred_non_adjust = svm_test_non_adjust['predicted_values']

# %%
fig =  plt.figure()
ax = plt.subplot(2,3,1)
#ax.scatter(ann_train_true_adjust, ann_train_pred_adjust, color = 'grey', alpha = 0.5, label = 'Train')
ax.scatter(ann_test_true_adjust, ann_test_pred_adjust, color = 'red', alpha = 0.5, label = 'Test')
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5) # set figure size 
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(-0.7,0.7)
plt.ylim(-0.7,0.7)
plt.title('ANN Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75) # create a diagonal line 
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.79
train_MAE = 0.12
train_N = 5275
test_r_squared = 0.29
test_MAE = 0.29
test_N = 1325
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
#plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
#plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')


ax = plt.subplot(2,3,2)
#plt.scatter(rf_y_train, rf_y_pred_train, color = 'grey', alpha = 0.5, label = 'Train')
plt.scatter(rf_test_true_adjust, rf_test_pred_adjust, color = 'red', alpha = 0.5, label = 'Test')
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-0.7,0.7)
plt.ylim(-0.7,0.7)
plt.title('RF Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.92
train_MAE = 0.12
train_N = 5275
test_r_squared = 0.32
test_MAE = 0.28
test_N = 1325
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
#plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
#plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')


ax = plt.subplot(2,3,3)
#plt.scatter(rf_y_train, rf_y_pred_train, color = 'grey', alpha = 0.5, label = 'Train')
plt.scatter(svm_test_true_adjust, svm_test_pred_adjust, color = 'red', alpha = 0.5, label = 'Test')
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-0.7,0.7)
plt.ylim(-0.7,0.7)
plt.title('SVM Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.92
train_MAE = 0.12
train_N = 5275
test_r_squared = 0.32
test_MAE = 0.28
test_N = 1325
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
#plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
#plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')



ax = plt.subplot(2,3,4)
#plt.scatter(rf_y_train, rf_y_pred_train, color = 'grey', alpha = 0.5, label = 'Train')
plt.scatter(ann_test_true_non_adjust, ann_test_pred_non_adjust, color = 'darkcyan', alpha = 0.5, label = 'Test')
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(-0.7,0.7)
plt.ylim(-0.7,0.7)
plt.title('ANN Non-Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.92
train_MAE = 0.12
train_N = 5275
test_r_squared = 0.32
test_MAE = 0.28
test_N = 1325
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
#plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
#plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')


ax = plt.subplot(2,3,5)
#plt.scatter(rf_y_train, rf_y_pred_train, color = 'grey', alpha = 0.5, label = 'Train')
plt.scatter(rf_test_true_non_adjust, rf_test_pred_non_adjust, color = 'darkcyan', alpha = 0.5, label = 'Test')
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-0.7,0.7)
plt.ylim(-0.7,0.7)
plt.title('RF Non-Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.92
train_MAE = 0.12
train_N = 5275
test_r_squared = 0.32
test_MAE = 0.28
test_N = 1325
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
#plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
#plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')


ax = plt.subplot(2,3,6)
#plt.scatter(rf_y_train, rf_y_pred_train, color = 'grey', alpha = 0.5, label = 'Train')
plt.scatter(svm_test_true_non_adjust, svm_test_pred_non_adjust, color = 'darkcyan', alpha = 0.5, label = 'Test')
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-0.7,0.7)
plt.ylim(-0.7,0.7)
plt.title('SVM Non-Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.92
train_MAE = 0.12
train_N = 5275
test_r_squared = 0.32
test_MAE = 0.28
test_N = 1325
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
#plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
#plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')
plt.subplots_adjust(bottom=0.3)

plt.savefig('True vs Pred PFAS.png')
