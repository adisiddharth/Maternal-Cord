# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats
# %matplotlib inline
import numpy as np
from sklearn.metrics import mean_absolute_error

# %%
# load in non-adjusted ANN csv (feature extracted)
ann_train_non = pd.read_csv('ANN_plus_tr_extract_base_non.csv')
ann_test_non = pd.read_csv('ANN_plus_ts_extract_base_non.csv')

# %%
# load in non-adjusted RF csv (feature extracted)
rf_train_non = pd.read_csv('forestplus_tr_extract_features4_non.csv')
rf_test_non = pd.read_csv('forestplus_ts_extract_features4_non.csv')

# %%
# load in non-adjusted SVM csv (feature extracted)
svm_train_non = pd.read_csv('svmdata_tr_non.csv')
svm_test_non = pd.read_csv('svmdata_ts_non.csv')

# %%
# load in adjusted ANN csv (feature extracted)
ann_train_adjust = pd.read_csv('ANN_plus_tr_L13_extract.csv')
ann_test_adjust = pd.read_csv('ANN_plus_ts_L13_extract.csv')

# %%
# load in adjusted RF csv (feature extracted)
rf_train_adjust = pd.read_csv('forestplus_tr_features_sqrt.csv')
rf_test_adjust = pd.read_csv('forestplus_ts_features_sqrt.csv')

# %%
# load in adjusted SVM csv (feature extracted)
svm_train_adjust = pd.read_csv('svmdata_tr_base_extract.csv')
svm_test_adjust = pd.read_csv('svmdata_ts_base_extract.csv')

# %% [markdown]
# # load in lipid adjusted ANN csv (All features)
# ann_train_all_adjusted = pd.read_csv('ANN_plus_tr_elu_adjusted.csv')
# ann_test_all_adjusted = pd.read_csv('ANN_plus_ts_elu_adjusted.csv')

# %% [markdown]
# # load in lipid adjusted RF csv (All features)
# rf_train_all_adjusted = pd.read_csv('forestplus_tr_leaf_4.csv')
# rf_test_all_adjusted = pd.read_csv('forestplus_ts_leaf_4.csv')

# %% [markdown]
# # load in lipid adjusted SVM csv (All features)
# svm_train_all_adjusted = pd.read_csv('svmdata_tr_base_adjusted.csv')
# svm_test_all_adjusted = pd.read_csv('svmdata_ts_base_adjusted.csv')

# %% [markdown]
# # load in non-lipid adjusted ANN csv (All features)
# ann_train_all_non_adjusted = pd.read_csv('ANN_plus_tr_D0.5.csv')
# ann_test_all_non_adjusted = pd.read_csv('ANN_plus_ts_D0.5.csv')

# %% [markdown]
# # load in non-lipid adjusted RF csv (All features)
# rf_train_all_non_adjusted = pd.read_csv('forestplus_tr_manual_all.csv')
# rf_test_all_non_adjusted = pd.read_csv('forestplus_ts_manual_all.csv')

# %% [markdown]
# # load in non-lipid adjusted SVM csv (All features)
# svm_train_all_non_adjusted = pd.read_csv('svmdata_tr_E0_non.csv')
# svm_test_all_non_adjusted = pd.read_csv('svmdata_ts_E0_non.csv')

# %%
# separate train and test from each graph
graph_1_train = ann_train_all_non_adjusted
graph_1_test = ann_test_all_non_adjusted

graph_2_train = rf_train_all_non_adjusted
graph_2_test = rf_test_all_non_adjusted

graph_3_train = svm_train_all_non_adjusted
graph_3_test = svm_test_all_non_adjusted

graph_4_train = ann_train_all_adjusted
graph_4_test = ann_test_all_adjusted

graph_5_train = rf_train_all_adjusted
graph_5_test = rf_test_all_adjusted

graph_6_train = svm_train_all_adjusted
graph_6_test = svm_test_all_adjusted

# %%
# separate true and pred values from test and train 
graph_1_train_true = graph_1_train['true_values']
graph_1_train_pred = graph_1_train['predicted_values']
graph_1_test_true = graph_1_test['true_values']
graph_1_test_pred = graph_1_test['predicted_values']

# %%
graph_2_train_true = graph_2_train['true_values']
graph_2_train_pred = graph_2_train['predicted_values']
graph_2_test_true = graph_2_test['true_values']
graph_2_test_pred = graph_2_test['predicted_values']

# %%
graph_3_train_true = graph_3_train['true_values']
graph_3_train_pred = graph_3_train['predicted_values']
graph_3_test_true = graph_3_test['true_values']
graph_3_test_pred = graph_3_test['predicted_values']

# %%
graph_4_train_true = graph_4_train['true_values']
graph_4_train_pred = graph_4_train['predicted_values']
graph_4_test_true = graph_4_test['true_values']
graph_4_test_pred = graph_4_test['predicted_values']

# %%
graph_5_train_true = graph_5_train['true_values']
graph_5_train_pred = graph_5_train['predicted_values']
graph_5_test_true = graph_5_test['true_values']
graph_5_test_pred = graph_5_test['predicted_values']

# %%
graph_6_train_true = graph_6_train['true_values']
graph_6_train_pred = graph_6_train['predicted_values']
graph_6_test_true = graph_6_test['true_values']
graph_6_test_pred = graph_6_test['predicted_values']

# %%
# plot the true vs pred graphs for lipid adjusted and non-lipid adjusted 

fig =  plt.figure()
ax = plt.subplot(2,3,1) # make a 2x3 grid and select the first one 
plt.scatter(graph_1_train_true, graph_1_train_pred, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
plt.scatter(graph_1_test_true, graph_1_test_pred, color = 'red', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5) # set figure size 
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('ANN Non-Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75) # plot a diagonal line 
plt.grid(True, linestyle='--', alpha = 0.5) # format line 
train_MAE = mean_absolute_error(graph_1_train_true, graph_1_train_pred) # train MAE
train_r = np.corrcoef(graph_1_train_true, graph_1_train_pred) # train R value
train_r_squared = train_r[0, 1]**2 # train R square 
train_N = len(graph_1_train_true) # train N 
test_MAE = mean_absolute_error(graph_1_test_true, graph_1_test_pred) # test MAE
test_r = np.corrcoef(graph_1_test_true, graph_1_test_pred) # test R value
test_r_squared = test_r[0, 1]**2 # test R square 
test_N = len(graph_1_test_true) # test N 
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared) # print and format the text 
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.5, -1.9, r'Test $Q^2$ = %0.2f' % test_r_squared)
plt.text(0.5, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.5, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100) # create a 100 points from -5 to 5 to draw a diagonal line 
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5) # format the lines 
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal') # set aspect ratio 



ax = plt.subplot(2,3,2)
plt.scatter(graph_2_train_true, graph_2_train_pred, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
plt.scatter(graph_2_test_true, graph_2_test_pred, color = 'red', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('RF Non-Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_MAE = mean_absolute_error(graph_2_train_true, graph_2_train_pred)
train_r = np.corrcoef(graph_2_train_true, graph_2_train_pred)
train_r_squared = train_r[0, 1]**2
train_N = len(graph_2_train_true)
test_MAE = mean_absolute_error(graph_2_test_true, graph_2_test_pred)
test_r = np.corrcoef(graph_2_test_true, graph_2_test_pred)
test_r_squared = test_r[0, 1]**2
test_N = len(graph_2_test_true)
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.5, -1.9, r'Test $Q^2$ = %0.2f' % test_r_squared)
plt.text(0.5, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.5, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')



ax = plt.subplot(2,3,3)
plt.scatter(graph_3_train_true, graph_3_train_pred, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
plt.scatter(graph_3_test_true, graph_3_test_pred, color = 'red', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
ax.legend(bbox_to_anchor=(1.05, 0), loc='lower left', borderaxespad=0., fontsize = 'x-large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('SVM Non-Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_MAE = mean_absolute_error(graph_3_train_true, graph_3_train_pred)
train_r = np.corrcoef(graph_3_train_true, graph_3_train_pred)
train_r_squared = train_r[0, 1]**2
train_N = len(graph_3_train_true)
test_MAE = mean_absolute_error(graph_3_test_true, graph_3_test_pred)
test_r = np.corrcoef(graph_3_test_true, graph_3_test_pred)
test_r_squared = test_r[0, 1]**2
test_N = len(graph_3_test_true)
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.5, -1.9, r'Test $Q^2$ = %0.2f' % test_r_squared)
plt.text(0.5, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.5, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')



ax = plt.subplot(2,3,4)
ax.scatter(graph_4_train_true, graph_4_train_pred, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
ax.scatter(graph_4_test_true, graph_4_test_pred, color = 'mediumseagreen', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('ANN Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_MAE = mean_absolute_error(graph_4_train_true, graph_4_train_pred)
train_r = np.corrcoef(graph_4_train_true, graph_4_train_pred)
train_r_squared = train_r[0, 1]**2
train_N = len(graph_4_train_true)
test_MAE = mean_absolute_error(graph_4_test_true, graph_4_test_pred)
test_r = np.corrcoef(graph_4_test_true, graph_4_test_pred)
test_r_squared = test_r[0, 1]**2
test_N = len(graph_4_test_true)
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.5, -1.9, r'Test $Q^2$ = %0.2f' % test_r_squared)
plt.text(0.5, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.5, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')




ax = plt.subplot(2,3,5)
plt.scatter(graph_5_train_true, graph_5_train_pred, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
plt.scatter(graph_5_test_true, graph_5_test_pred, color = 'mediumseagreen', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('RF Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_MAE = mean_absolute_error(graph_5_train_true, graph_5_train_pred)
train_r = np.corrcoef(graph_5_train_true, graph_5_train_pred)
train_r_squared = train_r[0, 1]**2
train_N = len(graph_5_train_true)
test_MAE = mean_absolute_error(graph_5_test_true, graph_5_test_pred)
test_r = np.corrcoef(graph_5_test_true, graph_5_test_pred)
test_r_squared = test_r[0, 1]**2
test_N = len(graph_5_test_true)
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.5, -1.9, r'Test $Q^2$ = %0.2f' % test_r_squared)
plt.text(0.5, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.5, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')



ax = plt.subplot(2,3,6)
plt.scatter(graph_6_train_true, graph_6_train_pred, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
plt.scatter(graph_6_test_true, graph_6_test_pred, color = 'mediumseagreen', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
ax.legend(bbox_to_anchor=(1.05, 0), loc='lower left', borderaxespad=0., fontsize = 'x-large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('SVM Lipid Adjusted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_MAE = mean_absolute_error(graph_6_train_true, graph_6_train_pred)
train_r = np.corrcoef(graph_6_train_true, graph_6_train_pred)
train_r_squared = train_r[0, 1]**2
train_N = len(graph_6_train_true)
test_MAE = mean_absolute_error(graph_6_test_true, graph_6_test_pred)
test_r = np.corrcoef(graph_6_test_true, graph_6_test_pred)
test_r_squared = test_r[0, 1]**2
test_N = len(graph_6_test_true)
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.5, -1.9, r'Test $Q^2$ = %0.2f' % test_r_squared)
plt.text(0.5, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.5, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')
plt.subplots_adjust(bottom=0.3)


#plt.savefig('Pred vs true adjusted vs non-adjusted all features.png', dpi = 300, bbox_inches = 'tight')

# %%
# load in non adjusted y-random RF csv (All features)
rf_train_y = pd.read_csv('forestplus_tr_all_y.csv')
rf_test_y = pd.read_csv('forestplus_ts_all_y.csv')

# %%
# load in non adjusted y-random ANN csv (All features)
ann_train_y = pd.read_csv('ANN_plus_tr_all_y.csv')
ann_test_y = pd.read_csv('ANN_plus_ts_all_y.csv')

# %%
# load in non adjusted y-random SVM csv (All features)
svm_train_y = pd.read_csv('svmdata_tr_all_y.csv')
svm_test_y = pd.read_csv('svmdata_ts_all_y.csv')

# %%
# load in non adjusted y-random RF csv (Feature Extracted)
rf_train_y_non = pd.read_csv('forestplus_tr_Y_non.csv')
rf_test_y_non = pd.read_csv('forestplus_ts_Y_non.csv')

# load in non adjusted y-random ANN csv (Feature Extracted)
ann_train_y_non = pd.read_csv('ANN_plus_tr_Y_non.csv')
ann_test_y_non = pd.read_csv('ANN_plus_ts_Y_non.csv')

# load in non adjusted y-random SVM csv (Feature Extracted)
svm_train_y_non = pd.read_csv('svmdata_tr_Y_non.csv')
svm_test_y_non = pd.read_csv('svmdata_ts_Y_non.csv')

# %%
# separate true and predicted in all features RF (y random)
rf_train_y_true_adjusted = rf_train_y['true_values']
rf_train_y_pred_adjusted = rf_train_y['predicted_values']
rf_test_y_true_adjusted = rf_test_y['true_values']
rf_test_y_pred_adjusted= rf_test_y['predicted_values']

# %%
# separate true and predicted in all features  ANN (y random)
ann_train_y_true_adjusted = ann_train_y['true_values']
ann_train_y_pred_adjusted = ann_train_y['predicted_values']
ann_test_y_true_adjusted = ann_test_y['true_values']
ann_test_y_pred_adjusted= ann_test_y['predicted_values']

# %%
# separate true and predicted in all features  SVM (y random)
svm_train_y_true_adjusted = svm_train_y['true_values']
svm_train_y_pred_adjusted = svm_train_y['predicted_values']
svm_test_y_true_adjusted = svm_test_y['true_values']
svm_test_y_pred_adjusted= svm_test_y['predicted_values']

# %%
# separate true and predicted in Feature Extracted RF (y random)
rf_train_y_true_non = rf_train_y_non['true_values']
rf_train_y_pred_non = rf_train_y_non['predicted_values']
rf_test_y_true_non = rf_test_y_non['true_values']
rf_test_y_pred_non = rf_test_y_non['predicted_values']

# separate true and predicted in Feature Extracted ANN (y random)
ann_train_y_true_non = ann_train_y_non['true_values']
ann_train_y_pred_non = ann_train_y_non['predicted_values']
ann_test_y_true_non = ann_test_y_non['true_values']
ann_test_y_pred_non = ann_test_y_non['predicted_values']

# separate true and predicted in Feature Extracted SVM (y random)
svm_train_y_true_non = svm_train_y_non['true_values']
svm_train_y_pred_non = svm_train_y_non['predicted_values']
svm_test_y_true_non = svm_test_y_non['true_values']
svm_test_y_pred_non = svm_test_y_non['predicted_values']

# %%
# plot true vs pred for lipid adjusted and non-lipid adjusted (y-randomization)
fig =  plt.figure()
ax = plt.subplot(2,3,1)
ax.scatter(ann_train_y_true_non, ann_train_y_pred_non, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
ax.scatter(ann_test_y_true_non, ann_test_y_pred_non, color = 'turquoise', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('ANN Feature Extracted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_MAE = 0.21
train_r_squared = 0.45
train_N = 5275
test_MAE = 0.45
test_r_squared = 0.0041
test_N = 1325
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.2, -1.9, r'Test $Q^2$ = %0.3f' % test_r_squared)
plt.text(0.2, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.2, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')



ax = plt.subplot(2,3,2)
plt.scatter(rf_train_y_true_non, rf_train_y_pred_non, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
plt.scatter(rf_test_y_true_non, rf_test_y_pred_non, color = 'turquoise', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('RF Feature Extracted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.9
train_MAE = 0.16
train_N = 5275
test_r_squared = 0.0013
test_MAE = 0.41
test_N = 1325
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.2, -1.9, r'Test $Q^2$ = %0.3f' % test_r_squared)
plt.text(0.2, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.2, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')



ax = plt.subplot(2,3,3)
plt.scatter(svm_train_y_true_non, svm_train_y_pred_non, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
plt.scatter(svm_test_y_true_non, svm_test_y_pred_non, color = 'turquoise', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
ax.legend(bbox_to_anchor=(1.05, 0), loc='lower left', borderaxespad=0., fontsize = 'x-large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('SVM Feature Extracted')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.32
train_MAE = 0.31
train_N = 5275
test_r_squared = 1.4e-05
test_MAE = 0.39
test_N = 1325
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.2, -1.9, r'Test $Q^2$ = %0.5f' % test_r_squared)
plt.text(0.2, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.2, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')



ax = plt.subplot(2,3,4)
ax.scatter(ann_train_y_true_adjusted, ann_train_y_pred_adjusted, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
ax.scatter(ann_test_y_true_adjusted, ann_test_y_pred_adjusted, color = 'magenta', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('ANN All Features')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.57
train_MAE = 0.18
train_N = 5275
test_r_squared = 0.001
test_MAE = 0.5
test_N = 1325
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.2, -1.9, r'Test $Q^2$ = %0.3f' % test_r_squared)
plt.text(0.2, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.2, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')




ax = plt.subplot(2,3,5)
plt.scatter(rf_train_y_true_adjusted, rf_train_y_pred_adjusted, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
plt.scatter(rf_test_y_true_adjusted, rf_test_y_pred_adjusted, color = 'magenta', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('RF All Features')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.9
train_MAE = 0.16
train_N = 5275
test_r_squared = 0.0008
test_MAE = 0.4
test_N = 1325
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.2, -1.9, r'Test $Q^2$ = %0.3f' % test_r_squared)
plt.text(0.2, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.2, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')



ax = plt.subplot(2,3,6)
plt.scatter(svm_train_y_true_adjusted, svm_train_y_pred_adjusted, color = 'grey', alpha = 0.5, label = 'Train', s = 5)
plt.scatter(svm_test_y_true_adjusted, svm_test_y_pred_adjusted, color = 'magenta', alpha = 0.2, label = 'Test', s = 5)
#legend = plt.legend(loc='lower right', shadow=True, fontsize='large')
ax.legend(bbox_to_anchor=(1.05, 0), loc='lower left', borderaxespad=0., fontsize = 'x-large')
fig.set_size_inches(12.5,12.5)
plt.xlabel('True Values')
#plt.ylabel('Predictions')
plt.xlim(-3,3)
plt.ylim(-3,3)
plt.title('SVM All Features')
_ = plt.plot([-100, 100], [-100, 100], color = 'black', alpha = 0.75)
plt.grid(True, linestyle='--', alpha = 0.5)
train_r_squared = 0.24
train_MAE = 0.32
train_N = 5275
test_r_squared = 2.4e-05
test_MAE = 0.39
test_N = 1325
plt.text(-2.5, 2.45, r'Train $Q^2$ = %0.2f' % train_r_squared)
plt.text(-2.5, 2.1, 'Train MAE = %0.2f' % train_MAE)
plt.text(-2.5, 1.7, 'Train N = %0.0f' % train_N)
plt.text(0.2, -1.9, r'Test $Q^2$ = %0.5f' % test_r_squared)
plt.text(0.2, -2.3, 'Test MAE = %0.2f' % test_MAE)
plt.text(0.2, -2.7, 'Test N = %0.0f' % test_N)
x = np.linspace(-5,5,100)
y1 = x+1
y2 = x-1
plt.plot(x, y1, '--', label='y=2x+1', color = 'black', alpha = 0.5)
plt.plot(x, y2, '--', label='y=2x+1',color = 'black', alpha = 0.5)
ax.set_aspect('equal')
plt.subplots_adjust(bottom=0.3)

plt.savefig('Pred vs true all features vs extracted y-random.png', dpi = 300, bbox_inches = 'tight')
