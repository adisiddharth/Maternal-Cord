# %%
# obtain the Morgan bits that are positively correlated 
# with log CM in MC_DB

# %%
from rdkit import DataStructs
from rdkit import Chem
from rdkit.Chem import AllChem
import numpy as np
from rdkit import Chem
from rdkit.Chem import rdMolDescriptors
from rdkit.Chem.Draw import IPythonConsole
from rdkit.Chem import Draw

# %% [markdown]
# # Bit 650

# %%
molecule1 = Chem.MolFromSmiles('[O-][N+](=O)C1=CC2=C(NC(=O)CN=C2C2=CC=CC=C2Cl)C=C1') # convert SMILES to mol format and store it
molecule1

# %%
bi1 = {} # initialize empty dict to pass into bitinfo
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1) # use the mol file to calculate Morgan fingerprint bits
fp_arr1 = np.zeros((1,)) # initialize empty numpy array
DataStructs.ConvertToNumpyArray(fp1, fp_arr1) # add the morgan bits to the empty numpy array
np.nonzero(fp_arr1) # Get the bits present in the molecule
# Out:
# (array([ 36,  64,  74,  90, 117, 124, 135, 142, 171, 175, 250, 314, 332,
#         352, 356, 366, 378, 429, 507, 512, 551, 561, 622, 624, 650, 659,
#         715, 724, 726, 753, 785, 790, 838, 849, 875, 881, 916, 926, 939,
#         958, 974, 984, 993], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,650,bi1) # Get the structure of the morgan bit (650 in this case)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99C43ABC8>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('CC1=CC=NC2=C1NC(=O)C1=CC=CN=C1N2C1CC1')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([  19,   23,   33,   36,   64,   90,  130,  297,  301,  314,  323,
#          333,  338,  352,  356,  367,  378,  402,  426,  428,  448,  456,
#          474,  527,  561,  633,  637,  650,  698,  726,  764,  787,  842,
#          849,  886,  898,  926,  935,  984, 1019], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,650,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99C440688>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('CC(NC(C)(C)C)C(=O)C1=CC=CC(Cl)=C1')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([  1,  15,  33,  54,  64, 114, 128, 165, 216, 283, 329, 356, 361,
#         386, 392, 524, 561, 592, 599, 603, 650, 659, 692, 726, 807, 834,
#         849, 875, 893, 932, 961, 989], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,650,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99C447648>

# %%
img.save("molecule3.png")

# %% [markdown]
# # Bit 59

# %%
molecule1 = Chem.MolFromSmiles('ClC1=CC=CC(Cl)=C1NC1=NCCN1')
molecule1

# %%
bi1 = {}
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1)
fp_arr1 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp1, fp_arr1)
np.nonzero(fp_arr1)
# Out:
# (array([ 15,  59,  64,  89,  90, 128, 256, 272, 305, 313, 356, 366, 378,
#         381, 383, 425, 491, 555, 561, 659, 726, 800, 836, 842, 849, 881,
#         926, 974], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,59,bi1)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99C461C48>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('ClC1C2C(C3OC13Cl)C1(Cl)C(Cl)=C(Cl)C2(Cl)C1(Cl)Cl')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([  36,   46,   59,   73,  113,  200,  210,  356,  396,  481,  493,
#          497,  554,  561,  605,  639,  656,  659,  668,  777,  808,  936,
#         1009, 1019], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,59,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99C453688>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('COC1=CC=C(C(=O)C2=CC=CC=C2)C(O)=C1')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([  9,  33,  59,  64,  67, 175, 205, 322, 356, 361, 389, 406, 512,
#         578, 583, 650, 695, 718, 726, 745, 751, 781, 807, 841, 849, 875,
#         893, 948, 961, 967], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,59,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99C45F048>

# %%
img.save("molecule3.png")

# %% [markdown]
# # Bit 145

# %%
molecule1 = Chem.MolFromSmiles('COC1=CC2=C(C=C1)N(C(=O)C1=CC=C(Cl)C=C1)C(C)=C2CC(O)=O')
molecule1

# %%
bi1 = {}
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1)
fp_arr1 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp1, fp_arr1)
np.nonzero(fp_arr1)
# Out:
# (array([  33,   45,   46,   60,   80,  116,  145,  216,  239,  258,  322,
#          325,  333,  356,  359,  361,  389,  480,  487,  512,  561,  609,
#          650,  659,  673,  695,  698,  713,  716,  718,  726,  742,  781,
#          807,  816,  841,  849,  858,  875,  893,  914,  935,  948,  997,
#         1010], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,145,bi1)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99D3B9B88>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('CCOC(=O)C1=CC=C(C=C1)N(C)C')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([ 33,  72,  80, 139, 145, 147, 214, 294, 355, 356, 361, 498, 606,
#         650, 673, 676, 695, 698, 726, 737, 759, 807, 849, 881, 893, 960],
#        dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,145,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99D3990C8>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('CCCCC(CC)COC(=O)C1=CC=C(C=C1)N(C)C')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([  1,  33,  72,  80, 118, 139, 145, 147, 190, 194, 205, 294, 304,
#         355, 356, 361, 396, 498, 520, 591, 606, 650, 673, 676, 695, 726,
#         727, 737, 739, 746, 794, 807, 849, 881, 887, 893, 960], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,145,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99CED0C08>

# %%
img.save("molecule3.png")

# %% [markdown]
# # Bit 906

# %%
molecule1 = Chem.MolFromSmiles('COC(=O)C1C(C2=C(C=CC=C2)[N+]([O-])=O)C(C(=O)OC)=C(C)N=C1C')
molecule1

# %%
bi1 = {}
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1)
fp_arr1 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp1, fp_arr1)
np.nonzero(fp_arr1)
# Out:
# (array([   3,    4,   33,   36,   42,   64,  128,  143,  145,  164,  171,
#          175,  348,  354,  356,  371,  378,  387,  429,  434,  495,  497,
#          534,  557,  650,  675,  695,  698,  715,  716,  722,  726,  753,
#          807,  838,  841,  849,  884,  893,  906,  927,  939, 1019],
#        dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,906,bi1)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99D3765C8>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('COC(=O)C1=C(C=CC=C1)C(O)=O')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([ 23,  33,  64, 128, 145, 175, 356, 389, 423, 456, 623, 650, 695,
#         726, 807, 823, 841, 849, 893, 906, 936, 967], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,906,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99D3F8DC8>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('CC(C)C1=CC2=C(SC3=C(C=CC=C3)C2=O)C=C1')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([  1,  33,  64, 157, 162, 175, 283, 314, 333, 341, 356, 461, 525,
#         549, 572, 598, 603, 648, 650, 675, 711, 720, 726, 780, 822, 829,
#         849, 875, 885, 906], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,906,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99D76F808>

# %%
img.save("molecule3.png")

# %% [markdown]
# # Bit 698

# %%
molecule1 = Chem.MolFromSmiles('CC1=NC=C2CN=C(C3=CC=CC=C3F)C3=CC(Cl)=CC=C3N12')
molecule1

# %%
bi1 = {}
fp1 = AllChem.GetMorganFingerprintAsBitVect(molecule1, 2, nBits=1024, bitInfo = bi1)
fp_arr1 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp1, fp_arr1)
np.nonzero(fp_arr1)
# Out:
# (array([  8,  33,  64, 109, 124, 135, 165, 175, 216, 239, 271, 326, 352,
#         356, 378, 428, 433, 451, 511, 539, 561, 624, 659, 686, 698, 699,
#         724, 726, 789, 816, 831, 843, 849, 875, 881, 891, 904, 917, 926,
#         935, 962, 969, 984], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule1,698,bi1)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99DDA6E88>

# %%
img.save("molecule1.png")

# %%
molecule2 = Chem.MolFromSmiles('CC1=CC=NC2=C1NC(=O)C1=CC=CN=C1N2C1CC1')
molecule2

# %%
bi2 = {}
fp2 = AllChem.GetMorganFingerprintAsBitVect(molecule2, 2, nBits=1024, bitInfo = bi2)
fp_arr2 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp2, fp_arr2)
np.nonzero(fp_arr2)
# Out:
# (array([  19,   23,   33,   36,   64,   90,  130,  297,  301,  314,  323,
#          333,  338,  352,  356,  367,  378,  402,  426,  428,  448,  456,
#          474,  527,  561,  633,  637,  650,  698,  726,  764,  787,  842,
#          849,  886,  898,  926,  935,  984, 1019], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule2,698,bi2)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99D3A00C8>

# %%
img.save("molecule2.png", size=(10000, 10000))

# %%
molecule3 = Chem.MolFromSmiles('COC1=CC2=C(C=C1)N(C(=O)C1=CC=C(Cl)C=C1)C(C)=C2CC(O)=O')
molecule3

# %%
bi3 = {}
fp3 = AllChem.GetMorganFingerprintAsBitVect(molecule3, 2, nBits=1024, bitInfo = bi3)
fp_arr3 = np.zeros((1,))
DataStructs.ConvertToNumpyArray(fp3, fp_arr3)
np.nonzero(fp_arr3)
# Out:
# (array([  33,   45,   46,   60,   80,  116,  145,  216,  239,  258,  322,
#          325,  333,  356,  359,  361,  389,  480,  487,  512,  561,  609,
#          650,  659,  673,  695,  698,  713,  716,  718,  726,  742,  781,
#          807,  816,  841,  849,  858,  875,  893,  914,  935,  948,  997,
#         1010], dtype=int64),)

# %%
img = Draw.DrawMorganBit(molecule3,698,bi3)
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=150x150 at 0x1C99D745888>

# %%
img.save("molecule3.png")
