# %%
# plot the distribution of the PFAS log CM prediction

# %%
ANN = pd.read_csv('ANN_plus_ts.csv') # load in Artificial Neural Net data
RF = pd.read_csv('forestplus_ts.csv') # load in random forest data
SVM = pd.read_csv('svmdata_ts.csv') # load in support vector machine data

# %%
ANN.pop('Unnamed: 0') # remove reduntant index column
ANN['mean_pred'] = ANN.mean(axis = 1) # take average of all the column into a new column named 'mean_pred'
ANN.head()
# Out:
#    predicted_values  predicted_values.1  predicted_values.2  \
# 0          0.237575            0.538335            0.194882
# 1          0.218181            0.670199            0.240652
# 2          0.261486            0.389663            0.157779
# 3         -0.106146           -0.378805           -0.197334
# 4         -0.149474           -0.346185           -0.254317
#
#    predicted_values.3  predicted_values.4  predicted_values.5  \
# 0            0.053612            0.237067            0.504859
# 1            0.000848            0.217364            0.810094
# 2            0.068593            0.186151            0.468243
# 3           -0.017311           -0.636959           -0.126898
# 4           -0.029771           -0.648926           -0.163248
#
#    predicted_values.6  predicted_values.7  predicted_values.8  \
# 0            0.207810            0.118766            0.135225
# 1            0.380020            0.307892            0.086682
# ...

# %%
RF.pop('Unnamed: 0')
RF['mean_pred'] = RF.mean(axis = 1)
RF.head()
# Out:
#    predicted_values  predicted_values.1  predicted_values.2  \
# 0          0.065202            0.195747            0.261998
# 1          0.106614            0.206635            0.195157
# 2          0.105726            0.185274            0.191469
# 3         -0.162587           -0.219232           -0.135540
# 4         -0.103550           -0.213429           -0.131288
#
#    predicted_values.3  predicted_values.4  predicted_values.5  \
# 0            0.183935            0.183477            0.042950
# 1            0.221820            0.095749            0.058768
# 2            0.215467            0.190091            0.054136
# 3           -0.140338           -0.187902           -0.142354
# 4           -0.125189           -0.174550           -0.130563
#
#    predicted_values.6  predicted_values.7  predicted_values.8  \
# 0            0.021404            0.115187           -0.046162
# 1            0.027193            0.053926           -0.039675
# ...

# %%
SVM.pop('Unnamed: 0')
SVM['mean_pred'] = SVM.mean(axis = 1)
SVM.head()
# Out:
#    predicted_values  predicted_values.1  predicted_values.2  \
# 0          0.085846            0.117654            0.117043
# 1          0.003188            0.044957            0.050058
# 2          0.084820            0.139495            0.112646
# 3         -0.184136           -0.221291           -0.235897
# 4         -0.184856           -0.217914           -0.221051
#
#    predicted_values.3  predicted_values.4  predicted_values.5  \
# 0            0.077888            0.072912           -0.045969
# 1            0.052489            0.017478           -0.089726
# 2            0.113614            0.104369           -0.016977
# 3           -0.217253           -0.249307           -0.280358
# 4           -0.207334           -0.227326           -0.254280
#
#    predicted_values.6  predicted_values.7  predicted_values.8  \
# 0            0.042687            0.032149            0.067496
# 1            0.018124            0.009334            0.021837
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib.ticker import FormatStrFormatter


fig =  plt.figure()  
fig.set_size_inches(9,9) # set figure size 
ax = plt.subplot(2,2,1) # select first subplot in a 2x2 grid
plt.hist(dataset['logCM'], bins = 30, edgecolor='black') # plot histogram 
plt.xlabel('LogCM Non-Lipid Adjusted (MC_DB)')
plt.ylabel('Count')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.1f')) # use only 1 decimal point in the x axis
plt.xlim(-2.5,2.5) # set x limits


ax = plt.subplot(2,2,2)
plt.hist(ANN['mean_pred'], bins = 30, edgecolor='black')
fig.tight_layout()
plt.xlabel('ANN Pred LogCM Non-Adjusted (PFAS_DB)')
ax.xaxis.set_major_formatter(FormatStrFormatter('%.1f'))
plt.xlim(-1,1)

ax = plt.subplot(2,2,3)
plt.hist(RF['mean_pred'], bins = 30, edgecolor='black')
fig.tight_layout()
plt.xlabel('RF Pred LogCM Non-Adjusted (PFAS_DB)')
plt.ylabel('Count')
plt.xlim(-1.2,1.2)

ax = plt.subplot(2,2,4)
plt.hist(SVM['mean_pred'], bins = 30, edgecolor='black')
fig.tight_layout()
plt.xlabel('SVM Pred LogCM Non-Adjusted (PFAS_DB)')
plt.xlim(-0.7,0.7)

plt.savefig('Log CM Non-Lipid Adjusted MC_DB & PFAS_DB', dpi = 300, bbox_inches = 'tight')
